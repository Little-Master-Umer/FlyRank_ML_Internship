# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Little-Master-Umer/FlyRank_ML_Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## Lane: Refresh / Content Opportunity Scoring
#
# I chose the **Refresh / Content Opportunity Scoring **lane because it focuses on identifying which webpages should be reviewed first for updates based on observable search and content signals. This aligns with the starter dataset and pipeline provided in the internship. The goal is not to automatically update pages, but to create a ranked review queue that helps content teams prioritize their limited time using evidence from the data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Research Question: Which webpages should be reviewed first for content refresh based on observable search and engagement signals?
#
# Decision: Prioritize webpages for manual review and possible content updates.
#
# Unit of Analysis: One webpage (one content item).
#
# Output: A ranked score indicating how strongly a page should be considered for review.
#
# Action: SEO or content teams review the highest-ranked pages first and decide whether they should be refreshed, expanded, monitored, or left unchanged.
#
# Cost of a Wrong Recommendation: If a page is incorrectly recommended, time and effort may be spent reviewing a page that does not need attention. If an important page is missed, the team may overlook opportunities to improve search performance. Therefore, this project is intended to support human decision-making rather than replace it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains many webpages with measurable search and engagement signals. The number of pages, average impressions, and average CTR provide evidence that there is enough variation in the data to investigate which pages should be prioritized for review. These statistics motivate further analysis during the internship.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("FlyRank_ML_Internship/data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average impressions (90d):", round(df["impressions_90d"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# fatal: destination path 'FlyRank_ML_Internship' already exists and is not an empty directory.
# Number of pages: 30000
# Average impressions (90d): 5200.37
# Average CTR: 0.5107

# %%
# import os

# print(f"Current working directory: {os.getcwd()}\n")
# print("Contents of current directory:")
# !ls -F

# %%
# Clone the GitHub repository
#!git clone https://github.com/Little-Master-Umer/FlyRank_ML_Internship.git

# List the contents of the newly cloned directory to verify
#print("\nContents of FlyRank_ML_Internship repository:")
#!ls -F FlyRank_ML_Internship/

# %% [markdown]
# After cloning, the repository will be available at `/content/FlyRank_ML_Internship/`. Now you can adjust the path in the `pd.read_csv` command to point to the correct location, or change your working directory.

# %% [markdown]
# The `ls -F` command lists files and directories. Directories are marked with a `/` at the end. You can then use `!ls -F <directory_name>/` to explore subdirectories and locate your `data` folder.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project aims to provide decision-support, not automatic decision-making. It can identify patterns and rank webpages using observed search and engagement signals. Any recommendations should be reviewed by humans before action is taken.
#
# This project cannot prove that refreshing a page will improve rankings because the data is observational rather than experimental. It also cannot predict Google's ranking algorithm or establish causal relationships. The findings should be interpreted as measured patterns that may help prioritize review, not as guaranteed outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
